# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np

linear_data = np.array([2,4,6,8,10,12,14])
xvals = range(len(linear_data))

plt.figure()
plt.bar(xvals, linear_data, width=0.5, alpha = .25 )
# Out:
# <img src="data:image/png;base64,...">
# <Container object of 7 artists>
